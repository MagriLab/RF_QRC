# %% [markdown]
# # Solving Dynamical Systems using Reservoir Computing

# %%
from QRC.solvers import *
from QRC.systems import *
from QRC.post_process import *
from QRC.crc import *
from QRC.qrc import *
from QRC.validation import *
#numpy
import numpy as np
#plotting libraries
import matplotlib.pyplot as plt
import matplotlib.pylab as pl
import matplotlib as mpl
#scipy libraries
import sklearn
from skopt.space import Real
from skopt.learning import GaussianProcessRegressor as GPR
from skopt.learning.gaussian_process.kernels import Matern, WhiteKernel, Product, ConstantKernel
#time libraries
import h5py
import time
from datetime import date
from timeit import default_timer as timer
today = date.today()
from qiskit_aer import AerSimulator
from qiskit.visualization import plot_histogram
from qiskit_ibm_runtime import QiskitRuntimeService, Batch , Sampler
from qiskit.transpiler import PassManager
from qiskit_ibm_runtime.transpiler.passes.scheduling import (
    ASAPScheduleAnalysis,
    PadDynamicalDecoupling,
)
from qiskit.circuit.library import XGate
from sklearn.metrics import mean_squared_error 


mpl.rc('text', usetex = True)
mpl.rc('font', family = 'serif')
mpl.rcParams['text.usetex']

#TODO
# Add config file so that to run on HPC
# Out:
# True

# %% [markdown]
# # Select Systems and Parameters

# %%
#for Lorenz 63:
# if __name__ == "__main__":
#     dt = 0.01
#     tot_steps = 100000
#     upsample = 1
#     q0 =  np.array([7.432487609628195, 10.02071718705213, 29.62297428638419])
#     #q0 =  np.array([0, 1, 1])
#     N_transient = 2000


# save_fold = 'VPT_L63'
# system = Systems(dt,tot_steps,q0,upsample,N_transient)

# dim,N_lyap,N_t = system.set_param_lorenz63() # FOR MFE, N_t should be input so in set_param_MFE -- make it as input
# q = system.gen_data_lorenz63()


#for MFE:
if __name__ == "__main__":
    dt = 0.25
    tot_steps = 20000
    upsample = 1
    q0   = np.array([1, 0.07066, -0.07066, 0, 0, 0, 0, 0, 0]) 
    N_t = 2000
    N_transient = 1000

save_fold= 'MFE'
system = Systems(dt,tot_steps,q0,upsample,N_transient)
sys = 'MFE'
dim,N_lyap = system.set_param_MFE(N_t) 

run = False
save= False
load = True

if run:
    q = system.gen_data_MFE()

if save:
    fln = './data/MFE'+'MFE'+'_dt='+str(dt)+'_Nt='+str(N_t)+'_dim='+str(dim)+'_date='+str() # Enter Date
    hf = h5py.File(fln,'w')
    hf.create_dataset('q',data=q)
    hf.close()

if load:
    hf      = h5py.File('./data/MFE/'+'MFE'+'_dt='+str(dt)+'_Nt='+str(N_t)+'_dim='+str(dim)+'_date='+str('2023-07-31'))
    q       = np.array(hf.get('q'))
    hf.close()

# %% [markdown]
# # Pre-process input data

# %%
data_inputs = True
noise       = False # to add noise in flattened time series 
scaling     = False # to scale flattened time series 

if data_inputs:
    N_ts        = 1 # 1 for L63 and L96, 20 for MFE
    N_test_stat = 500 # Time series for testing after N_ts

    N_washout  = 2*N_lyap #10 before for L96 10 D , 2 before for L63 / MFE  
    N_val      = 2*N_lyap # 3 for L63 , # 5 for L96 , 2*N_lyap for MFE
    N_train    = 20*N_lyap #200 before for L96 10D , 20 before for L63 / MFE  
    N_test     = 200*N_lyap
 


# All above in this block are Inputs
q_unscaled = q
UU = q # backup of complete time series
print('Laminarized precentage', np.round(100-((q.shape[0])*100/N_t),2),'(relevant for MFE)')

q = q[:N_ts+N_test_stat,:,:] # trimmed time series

print('Retaining ',N_ts, 'series for training and validation')
print('Additional ',N_test_stat, 'series for testing and statistical predictions')

# Rescaling Input Time Series after flattening it (only retained series)
q0 = q.shape[0] # Total time series, Train+Val+Test
q1 = q.shape[1] # Length of each time series
q_U = q.reshape(q0*q1, dim)

if scaling:
    q = sklearn.preprocessing.minmax_scale(q_U, feature_range=(0, 1), axis=0, copy=True) # rescaling flattened array
    q  = q.reshape(q0,q1,dim) # making 3 dimensional again

# from here q has scaled data
q_tv = q[:N_ts,:,:]  # From q retaining training set (N_ts)
q_test = q[N_ts:N_ts+N_test_stat,:,:]  #From q removing retaining test set(N_test_stat)

# Training, Validation Parameters
UU = q_tv # Training, validation set
N0 = UU.shape[0] # Retained Time series for training
N1 = UU.shape[1] # Length of each time series
print('UU Size =',UU.shape) # 3 dim
U = UU.reshape(N0*N1, dim) # Generating flattened time series for addition of noise and normalization
print('U Size =',U.shape) # 2 dim 

if noise: # adding noise in training set
    target_snr_db=40
    seed=0
    UU = add_noise(U,target_snr_db,seed,dim,N0,N1)

#compute norm
U_data = U[:N_washout+N_train+N_val]
m = U_data.min(axis=0)
M = U_data.max(axis=0)
norm = M-m
u_mean = U_data.mean(axis=0)

# washout
U_washout = UU[:,:N_washout]
# training + validation
U_tv  = UU[:,N_washout:N_washout+N_train+N_val-1]
Y_tv  = UU[:,N_washout+1:N_washout+N_train+N_val]
# Testing
U_test  = UU[:,N_washout+N_train+N_val:N_washout+N_train+N_val+N_test-1]
Y_test  = UU[:,N_washout+N_train+N_val+1:N_washout+N_train+N_val+N_test]

print('N_lyap:', N_lyap)
print('N_train =',int(N_train/N_lyap),'N_lyap',' x ',str(N_ts),'series')
print('N =',int((N_washout+N_val+N_train)/N_lyap),'N_lyap',', Total steps of training=',int(N_washout+N_val+N_train),', Out of = ',N0*N1)
print('The shape of q_tv is '+str(q_tv.shape)+ ' to train on ' +str(N_ts)+  ' time series')
print('The shape of q_test is '+str(q_test.shape)+ ' to test ' +str(N_test_stat)+  ' time series, and for stats predictions (relevant for MFE)')
print('The shape of q is '+str(q.shape)+ ' combining above')
print('The shape of U_test is '+str(U_test.shape)+ ' combining above')
# Out:
# Laminarized precentage 27.95 (relevant for MFE)
# Retaining  1 series for training and validation
# Additional  500 series for testing and statistical predictions
# UU Size = (1, 16000, 9)
# U Size = (16000, 9)
# N_lyap: 245
# N_train = 20 N_lyap  x  1 series
# N = 24 N_lyap , Total steps of training= 5880 , Out of =  16000
# The shape of q_tv is (1, 16000, 9) to train on 1 time series
# The shape of q_test is (500, 16000, 9) to test 500 time series, and for stats predictions (relevant for MFE)
# The shape of q is (501, 16000, 9) combining above
# The shape of U_test is (1, 10120, 9) combining above

# %% [markdown]
# # Visualize input data

# %%
# l1 = 8000
# l2 = 5000
# l3 = 5000

# plot_lorenz63_attractor(U,l1)
# plot_lorenz63_time(U,N_lyap,l2,l3)
# plt.show()

# %% [markdown]
# # Classical Reservoir Initialization

# %%
# Required Input Parameters
bias_in   = np.array([np.mean(np.abs((U_data-u_mean)/norm))]) #input bias (average absolute value of the inputs)
bias_out  = np.array([1.]) #output bias 
N_units   = 1024 #neurons
density = 0.11 # L63
#density = 0.01 # L96
#connectivity = 30

# Predefining Hyperparameter to initiate a class
tikh = np.array([1e-9])  # Tikhonov factor 
sigma_in = 1 # input scaling
rho = 1
epsilon = 1

# Random Weight Matrices Seed
seed = 2

sparseness = 1 - density
connectivity = (1 -  sparseness)*(N_units-1)

# sparseness = 1-((connectivity)/(N_units-1))
# density    = 1-sparseness
print('Density(D) = ',np.round(density,2))
print('Connectivity = ', np.round(connectivity,2))

esn = EchoStateNetwork(tikh,sigma_in,rho,epsilon,bias_in,bias_out,N_units,dim,density)
esn.norm_u = norm
# Out:
# Density(D) =  0.11
# Connectivity =  112.53

# %% [markdown]
# # Validation (hyperparameter tuning)

# %%
n_in        = 10               #Number of Initial random points
n_tot       = 50               #Total number of function evaluations

#range for hyperparameters 
spec_in     = np.log10(0.01)   
spec_end    = np.log10(1.0)   
epsilon_in  = 0.01
epsilon_end = 1
scaling_in  = 0.01
scaling_end = 1
#Number of Networks in the ensemble
ensemble = 5      
    
search_space = [Real(spec_in, spec_end, name='spectral_radius'),
            Real(epsilon_in, epsilon_end, name='epsilon'),
            Real(scaling_in,scaling_end, name = 'input_scaling')]

kernell = ConstantKernel(constant_value=1.0, constant_value_bounds=(1e-1, 3e0)) *\
            Matern(length_scale=[0.2,0.1,0.3], nu=2.5, length_scale_bounds=(5e-2, 1e1)) 


k= 0
# Which validaton strategy (implemented in Val_Functions.ipynb)
val      = RVC_Noise_upt
N_fo     = max(50,2)            # number of validation intervals
N_in     = N_washout                  # timesteps before the first validation interval (can't be 0 due to implementation)
N_fw     = (N_train-N_val)//(N_fo-1) # how many steps forward the validation interval is shifted (in this way they are evenly spaced)

#Quantities to be saved
par      = np.zeros((ensemble, 5))      # GP parameters
x_iters  = np.zeros((ensemble,n_tot,len(search_space))) # coordinates in hp space where f has been evaluated
f_iters  = np.zeros((ensemble,n_tot))   # values of f at those coordinates
minimum  = np.zeros((ensemble, len(search_space)+2))      # minima found per each member of the ensemble

# to store optimal hyperparameters and matrices
tikh_opt = np.zeros(n_tot)
Woutt    = np.zeros(((ensemble, N_units+1,dim)))
Winn     = [] #save as list to keep single elements sparse
Ws       = [] 
biass    = []
rho_ens  = []
epsilon_ens = []
sigma_in_ens = []
Xa_cc        = []
LHS_cc       = []
RHS_cc       = []

# save the final gp reconstruction for each network
gps        = [None]*ensemble

# to print performance of every set of hyperparameters
# print_flag = False

# %%
## TODO fix k, global issues for classical hyperparam opt
run_hyperparam = False

if run_hyperparam:
    for i in range(ensemble):
        
        print('Realization    :',i+1)
        
        k   = 0
        
        # Win and W generation
        seed= i+1
        rnd = np.random.RandomState(seed)

        Win =  esn.gen_input_matrix(seed)
        W =  esn.gen_reservoir_matrix(seed)
        
        # Bayesian Optimization
        tt       = time.time()
        res      = validate(val,kernell,search_space,n_in,n_tot,esn,tikh,N_fo,N_fw,N_in,N_val,N_washout,U,U_washout,U_tv,Y_tv,Win,W,tikh_opt)
        print('Total time for the network:', time.time() - tt)
        
        #Saving Quantities for post_processing
        gps[i]     = res.models[-1]    
        gp         = gps[i]
        x_iters[i] = np.array(res.x_iters)
        f_iters[i] = np.array(res.func_vals)
        minimum[i] = np.append(res.x,[tikh_opt[np.argmin(f_iters[i])],res.fun])
        params     = gp.kernel_.get_params()
        key        = sorted(params)
        par[i]     = np.array([params[key[2]],params[key[5]][0], 1, gp.noise_,params[key[5]][1]])

        esn.rho      = 10**minimum[i,0]
        esn.epsilon  = minimum[i,1]
        esn.sigma_in = minimum[i,2]

        Woutt[i] = esn.train(U_washout, U_tv, Y_tv,Win,W)[1]

        Winn    += [Win] 
        Ws      += [W]   

        #Plotting Optimization Convergence for each network
        print('Best Results: x', 10**minimum[i,0], minimum[i,1],minimum[i,2] ,minimum[i,3],', Min Obj Function =', minimum[i,4])
        print('Hyperparamters:',esn.rho,esn.epsilon,esn.sigma_in)

        plt.rcParams["figure.figsize"] = (15,2)

# %% [markdown]
# # Loading Hyperparameters

# %%
#hf       = h5py.File('./data/VPT_L96/minimum='+str(dt)+'-Nres'+str(N_units)+'-Ensemble'+str(ensemble)+'-dim'+str(dim)) # L96 without noise , its the file for paper
# hf       = h5py.File('./data/VPT_L96/minimum='+str(dt)+'-Nres'+str(N_units)+'-Ensemble'+str(ensemble)+'-dim'+str(dim)+'-noise') # L96 with noise , paper results
#hf       = h5py.File('./data/VPT_L96/minimum='+str(dt)+'-Nres'+str(N_units)+'-Ensemble'+str(ensemble)+'-dim'+str(dim)+'-noise'+str(noise)+'new')

# hf       = h5py.File('./data/VPT_L63/minimum='+str(dt)+'-Nres'+str(N_units)+'-Ensemble'+str(ensemble)+'-noise')
# hf       = h5py.File('./data/VPT_L63/minimum='+str(dt)+'-Nres'+str(N_units)+'-Ensemble'+str(ensemble)+'-noise'+str(noise))
# hf       = h5py.File('./data/VPT_L63/minimum='+str(dt)+'-Nres'+str(N_units)+'-Ensemble'+str(ensemble))
# minimum       = np.array(hf.get('minimum'))
# hf.close()

#hf       = h5py.File('./data/MFE/minimum='+str(dt)+'-Nres'+str(N_units)+'-Ensemble'+str(ensemble)+'-dim'+str(dim)+'-noise') # With Noise
hf       = h5py.File('./data/MFE/minimum='+str(dt)+'-Nres'+str(N_units)+'-Ensemble'+str(ensemble)+'-dim'+str(dim)) # Without noise
minimum       = np.array(hf.get('minimum'))
hf.close()


for i in range(ensemble):
    print('Realization    :',i+1)

    esn.rho      = 10**minimum[i,0]
    esn.epsilon  = minimum[i,1]
    esn.sigma_in = minimum[i,2]
    seed= i+1
    rnd = np.random.RandomState(seed)
    
    Win =  esn.gen_input_matrix(seed)
    W =  esn.gen_reservoir_matrix(seed)
    
    Xa, Wout_p, LHS, RHS =  esn.train(U_washout, U_tv, Y_tv,Win,W)
    
    Woutt[i] = Wout_p
    
    Winn    += [Win] 
    Ws      += [W]
    Xa_cc   += [Xa]
    LHS_cc  += [LHS]
    RHS_cc  += [RHS]
# Out:
# Realization    : 1
# Realization    : 2
# Realization    : 3
# Realization    : 4
# Realization    : 5

# %% [markdown]
# # Quantum Reservoir Computing - Initialization

# %%
# Defining Qbit and Cbits
n              = 10 # 9 Qubits and classical
Nres           = 2**n # Total Reservoir Size
qubits         = n

# Required Input Parameters
N_units_q      = Nres #neurons or N_res in paper
bias_in        = np.array([np.mean(np.abs((U_data-u_mean)/norm))])  # Input bias, b_in to break the inherent symmetry of ESN Structure
bias_out       = np.array([1]) #output bias 

# Hyperparameters
tikh_q        = np.array([1e-12])  # Tikhonov Param (Beta),  adds a regularization or weight decay term that penalizes large Wout values 
sigma_in_q    = 1
rho_q         = 1.0 # [Spectral Radius]
epsilon_q     = 1 # Leaking Rate

# Ensembles for QRC
qu_ensemble   = 1

# %% [markdown]
# # Simulated Shot Noise

# %%
Configurations = ['Linear+Full+FullSymmetric','Linear+Linear+Linear','None+Linear+Linear','None+Full+FullSymmetric','None+Products+Linear']
config_list    = ['config1','config2','config3','config4','config5']
qc_type        = config_list[3]
config         = 4 # for initializing class its +1 of the list above

emulator_list  = ['sv_sim','qasm_sim','fake_kyoto']
emulator       = emulator_list[1]

method_list    = ['sv','shots1k','shots5k','shots10k','shots20k','shots30k','shots40k','shots50k','shots75k','shots100k','shots200k','shots1']
shot_list      = [None,1000,5000,10000,20000,30000,40000,50000,75000,100000,200000,400000,1]

## SHOT INPUT
shot_index     = 3

method = method_list[shot_index]
total_shots  = shot_list[shot_index]


shots = total_shots

snapshots = 1
print('Configuration:',qc_type,'Emulator:',emulator,'Total shots:',total_shots,'Individual Shots:',shots)

# Initialize Class
QESN   = QuantumReservoirNetwork(rho_q,epsilon_q,sigma_in_q,tikh_q,bias_in,bias_out,qubits,N_units_q,dim,config,emulator,shots,snapshots)

# Parameterized or not
QESN.method_qc(parameterized=False)

# Generate parameterized quantum circuit for a given configuration
# QESN.gen_param_quantumcircuit()

quantum_training = True
run_training     = True
save_training    = False
load_training    = False

Xa_qq    = []
Woutt_qq    = np.zeros(((qu_ensemble, QESN.N_units+1,dim)))
LHS_qq   = []
RHS_qq   = []
alpha_qc = []

eps_fix  = 1 ### 0.05
tikh_q   = np.array([1e-12])
eps_q_list = np.linspace(0.05,0.3,qu_ensemble)
eps_q_list = np.ones(len(eps_q_list))*eps_fix
alpha_range    = 4*np.pi

start = timer()

if quantum_training:
    for i in range(qu_ensemble):
        
        print('Network',i+1,' out of ',qu_ensemble)
        seed           = i
        
        # Quantum Variational Part
        QESN.epsilon_q = eps_q_list[i]

        alpha_q          = QESN.gen_random_unitary(i,alpha_range)
        alpha_qc        += [alpha_q]


        if load_training:
            print('Loading existing Wout matrix')
            #hf       = h5py.File('./data/MFE/Woutt_qq='+str(dt)+'-Nres'+str(N_units_q)+'-Ensemble'+str(ensemble)+'-dim'+str(dim)+'-epsilon_q'+str(eps_fix)+'-tikh'+str(tikh_q)+'script')#+'-noise')
            #hf        = h5py.File('./data/MFE/Woutt_qq='+str(dt)+'-Nres'+str(N_units)+'-Ensemble'+str(qu_ensemble)+'-dim'+str(dim)+'-epsilon_q'+str(eps_fix)+'-tikh'+str(tikh_q)+'-scaling'+str(scaling)+'-noise'+str(noise)+'-'+str(method)+str(qc_type))
            hf       = h5py.File('./data/VPT_L63/Woutt_qq='+str(dt)+'-Nres'+str(N_units)+'-Ensemble'+str(ensemble)+'-dim'+str(dim)+'-epsilon_q'+str(eps_fix)+'-tikh'+str(tikh_q)+'-scaling'+str(scaling)+'-noise'+str(noise)+'-'+str(method)+str(qc_type))
            #hf      = h5py.File('./data/{}_New/Woutt_qq='.format(save_fold)+str(dt)+'-Nres'+str(N_units)+'-Ensemble'+str(qu_ensemble)+'-dim'+str(dim)+'-epsilon_q'+str(eps_fix)+'-tikh'+str(tikh_q)+'-scaling'+str(scaling)+'-noise'+str(noise)+'-'+str(method)+str(qc_type))
            #hf      = h5py.File('./data/{}/Woutt_qq='.format(save_fold)+str(dt)+'-Nres'+str(N_units)+'-Ensemble'+str(qu_ensemble)+'-dim'+str(dim)+'-epsilon_q'+str(eps_fix)+'-tikh'+str(tikh_q)+'-scaling'+str(scaling)+'-noise'+str(noise)+'-'+str(method)+str(qc_type))
            
            Woutt_qq       = np.array(hf.get('Woutt_qq'))
            hf.close()
        

        if run_training:
            print('Training...')
            # Xa_qc, Woutt_qc, LHS_qc, RHS_qc = QESN.quantum_training(U_washout, U_tv, Y_tv, alpha_qc[i])
            Xa_qc, Woutt_qc, LHS_qc, RHS_qc = QESN.quantum_training(U_washout[:,-2:-1,:], U_tv, Y_tv, alpha_qc[i]) # Washout not incorporated in U_tv
                    
            Xa_qq       += [Xa_qc]
            Woutt_qq[i]  = Woutt_qc # saving Output matrix as array 
            LHS_qq      += [LHS_qc]
            RHS_qq      += [RHS_qc]
                
alpha_qq = alpha_qc
# Woutt_qq = Woutt_qq

if load_training:
    Woutt_qq = np.reshape(Woutt_qq,[qu_ensemble, QESN.N_units+1,dim]) # If loading previously saved Woutt , need to reshape 4D to 2D

end = timer()

training_time = (end-start)
print(training_time)


if save_training:
    fln      = ('./data/{}/Woutt_qq='.format(save_fold)+str(dt)+'-Nres'+str(N_units)+'-Ensemble'+str(qu_ensemble)+'-dim'+str(dim)+'-epsilon_q'+str(eps_fix)+'-tikh'+str(tikh_q)+'-scaling'+str(scaling)+'-noise'+str(noise)+'-'+str(method)+str(qc_type))
    hf       = h5py.File(fln,'w')
    hf.create_dataset('Woutt_qq',data=Woutt_qq)
    hf.close()
# Out:
# Configuration: config4 Emulator: qasm_sim Total shots: 10000 Individual Shots: 10000
# Network 1  out of  1
# Training...
# 464.9375287052244

# %%
runs = 630

for i in range(U_washout.shape[0]):
    R_open_o = QESN.quantum_openloop(U_tv[i][:runs],np.zeros(N_units),alpha_qc[0])

# %%
R_open = R_open_o[1:,:-1]
R_open = R_open.T

R_train = Xa_qc[0][:,:-1]
R_train = R_train.T

# %%
plt.rcParams['text.usetex'] = True
plt.rcParams["figure.figsize"] = (6,4)
plt.rcParams["font.size"] = 12

plt.plot(R_open[:,:].T,label='openloop')
plt.plot(R_train[:,:runs].T,label='training')
plt.title('Simulated Noise without recurrence')
# plt.legend()
plt.show()

# %%
epsilon_q = 0.05
shots = 10000
RR_open = np.zeros([R_open.shape[0],R_open.shape[1]])
RR_train = np.zeros([R_open.shape[0],R_open.shape[1]])

for x in range(R_open.shape[1]):
    prob_tilde = R_open[:,x]
    
    if x>0:
        prob_neweps = (1-epsilon_q)*RR_open[:,x-1]+epsilon_q*prob_tilde # including epsilon_q/leaking rate
    else:
        prob_neweps = prob_tilde

    RR_open[:,x] = prob_neweps
    
    
for x in range(R_open.shape[1]):
    prob_tilde = R_train[:,x]
    
    if x>0:
        prob_neweps = (1-epsilon_q)*RR_train[:,x-1]+epsilon_q*prob_tilde # including epsilon_q/leaking rate
    else:
        prob_neweps = prob_tilde

    RR_train[:,x] = prob_neweps

# %%
plt.rcParams['text.usetex'] = True
plt.rcParams["figure.figsize"] = (6,4)
plt.rcParams["font.size"] = 12

plt.plot(RR_open[1000,:].T,label='openloop')
plt.plot(RR_train[1000,:].T,label='training')
plt.title('Simulated Noise with ''added'' recurrence')
plt.legend()
plt.show()

# %%
import pickle

with open("results_qc_ibm_kyoto_MFE_0_120", "rb") as fp:   # Unpickling
   result1 = pickle.load(fp)
   
with open("results_qc_ibm_kyoto_MFE_120_250", "rb") as fp:   # Unpickling
   result2 = pickle.load(fp)
   
with open("results_qc_ibm_kyoto_MFE_250_380", "rb") as fp:   # Unpickling
   result3 = pickle.load(fp)
   
with open("results_qc_ibm_kyoto_MFE_380_500", "rb") as fp:   # Unpickling
   result4 = pickle.load(fp)
   
with open("results_qc_ibm_kyoto_MFE_500_630", "rb") as fp:   # Unpickling
   result5 = pickle.load(fp)

# %%
shots = 10000
rr = np.zeros([N_units,runs])
r_noise  = np.zeros([N_units,runs])

for x in range(runs):
    if x < 120:
        # print(x)
        counts = [k for k in result1.quasi_dists][x]
    elif x >= 120 and x < 250 :
        # print(x,x-120)
        counts = [k for k in result2.quasi_dists][x-120]
    elif x>=250 and x < 380:
        # print(x,x-250)
        counts = [k for k in result3.quasi_dists][x-250]
    elif x>=380 and x < 500:
        # print(x,x-250)
        counts = [k for k in result3.quasi_dists][x-380]
    elif x>=500:
        # print(x,x-250)
        counts = [k for k in result3.quasi_dists][x-500]
        

    a=list(np.zeros(N_units))

    for ll in range(N_units):
        a[ll]= 0+1024*ll

    # Turning count in terms of probabilities
    psi_tilde = {}
    for output in list(a):
        if output in counts:
            psi_tilde[output] = counts[output]
        else:
            psi_tilde[output] = 0

    #psi_tilde = dict(sorted(psi_tilde.items())) # sorting dictionary with binary number 0s ---> higher

    psi_tilde = np.array([j for j in psi_tilde.values()]) #Takes values of probabilities from the dictionary

    prob_tilde = (psi_tilde)
    
    # if x>0:
    #     prob_neweps = (1-epsilon_q)*rr[:,x-1]+epsilon_q*prob_tilde # including epsilon_q/leaking rate
    # else:
    #     prob_neweps = prob_tilde

    # rr[:,x] = prob_neweps
    r_noise[:,x] = prob_tilde

# %%
epsilon_q = 0.05
shots = 10000
R_backend = r_noise
RR_backend = np.zeros([R_backend.shape[0],R_backend.shape[1]])

for x in range(R_backend.shape[1]):
    prob_tilde = R_backend[:,x]
    
    if x>0:
        prob_neweps = (1-epsilon_q)*RR_backend[:,x-1]+epsilon_q*prob_tilde # including epsilon_q/leaking rate
    else:
        prob_neweps = prob_tilde

    RR_backend[:,x] = prob_neweps

# %%
plt.rcParams['text.usetex'] = True
plt.rcParams["figure.figsize"] = (12,4)
plt.rcParams["font.size"] = 12
r_washout = 50
# y_max = 0.004
# no recurrency
plt.subplot(1,2,1)
plt.title('Backend, no recurrence')
plt.plot(R_backend[:,:].T)
# plt.ylim([0,y_max])
plt.subplot(1,2,2)
plt.title('Simulated, no recurrence')
plt.plot(R_open[:,:].T)
# plt.ylim([0,y_max])
plt.show()
# added recurrency
plt.subplot(1,2,1)
plt.title('Backend, added recurrence')
plt.plot(RR_backend[:,r_washout:].T)
# plt.ylim([0,y_max])
# plt.show()
plt.subplot(1,2,2)
plt.title('Simulated, added recurrence')
plt.plot(RR_open[:,r_washout:].T)
# plt.ylim([0,y_max])
plt.show()

# %%
plt.plot(RR_backend[:,1])
plt.plot(RR_open[:,1])

# %%
plt.rcParams['text.usetex'] = True
plt.rcParams["figure.figsize"] = (12,4)
plt.rcParams["font.size"] = 12
state = 100
plt.subplot(1,2,1)
plt.plot(R_backend[state,r_washout:].T)
plt.subplot(1,2,2)
plt.plot(R_open[state,r_washout:].T)
plt.show()

# %%
plt.rcParams['text.usetex'] = True
plt.rcParams["figure.figsize"] = (14,4)
plt.rcParams["font.size"] = 12
res_state = [1,2,3,4,5,6,7,8,9]

plt.subplot(1,2,1)
plt.title('Added recurrence')
plt.plot(RR_backend[res_state,:].T,label='backend')
plt.plot(RR_open[res_state,:].T,label='simulated')
# plt.legend()
plt.subplot(1,2,2)
plt.title('No recurrence')
plt.plot(R_backend[res_state,:].T,label='backend')
plt.plot(R_open[res_state,:].T,label='simulated')
# plt.legend()


plt.show()

# %%
plt.subplot(1,2,1)
plt.title('Backend, added recurrence')
plt.plot(RR_backend[:,r_washout:].T)
plt.subplot(1,2,2)
plt.title('Simulated, added recurrence')
plt.plot(RR_open[:,r_washout:].T)
plt.show()

# %%
Res_backend = RR_backend[:,r_washout:]
Res_open    = RR_open[:,r_washout:]

# %%
RR_backend.shape
# Out:
# (1024, 630)

# %%
# Denoised
# qq_test_dn = np.zeros([q_test_dn.shape[0],q_test_dn.shape[1]])

plt.rcParams['text.usetex'] = True
plt.rcParams["figure.figsize"] = (14,4)
plt.rcParams["font.size"] = 12


qq_backend_dn = np.zeros([Res_backend.shape[0],Res_backend.shape[1]])
qq_open_dn = np.zeros([Res_open.shape[0],Res_open.shape[1]])
freq = 10
poly = 3


qq_backend = Res_backend
qq_open    = Res_open


num_state = 1024

for i in range(num_state): # de noising all states
    #plt.plot(pp[:-1,i])
    qq_backend_dn[i] = savgol_filter(qq_backend[i], window_length = freq, polyorder=poly)
    qq_open_dn[i] = savgol_filter(qq_open[i], window_length = freq, polyorder=poly)

# %%
plt.plot(qq_backend[1020,:].T,label='noisy')
plt.plot(qq_backend_dn[1020,:].T,label='denoised')
plt.legend()
plt.show()

# %%
plt.subplot(1,2,1)
plt.title('Noisy -- Backend, added recurrence')
plt.plot(qq_backend.T)
plt.subplot(1,2,2)
plt.title('Noisy -- Simulated, added recurrence')
plt.plot(qq_open.T)
plt.show()


plt.subplot(1,2,1)
plt.title('Denoised -- Backend, added recurrence')
plt.plot(qq_backend_dn.T)
plt.subplot(1,2,2)
plt.title('Denoised -- Simulated, added recurrence')
plt.plot(qq_open_dn.T)
plt.show()

# %%
Y_tv_lim = Y_tv[0][:Res_backend.shape[1],:]

lim_qq_list = np.linspace(10,N_units_q,40)

mse_backend_dn         = np.zeros([lim_qq_list.shape[0]])
mse_open_dn         = np.zeros([lim_qq_list.shape[0]])


mse_backend         = np.zeros([lim_qq_list.shape[0]])
mse_open         = np.zeros([lim_qq_list.shape[0]])

# y_pred_backend_dn         = np.zeros([lim_qq_list.shape[0],Y_tv_lim.shape[0],dim])
# y_pred_open_dn            = np.zeros([lim_qq_list.shape[0],Y_tv_lim.shape[0],dim])


for i in range(lim_qq_list.shape[0]):
        
    lim_qq = int(lim_qq_list[i])
    
    LHS = np.dot(qq_backend[:lim_qq,:],qq_backend[:lim_qq].T)
    RHS = np.dot(qq_backend[:lim_qq,:],Y_tv_lim)
    #solve linear system for each tikh_qonov parameter
    Wout_q = np.zeros((tikh_q.size, lim_qq,dim))

    for j in np.arange(tikh_q.size):
        Wout_q[j] = np.linalg.solve(LHS + tikh_q[j]*np.eye(lim_qq), RHS)
        
    Wout_q = Wout_q[0]

    y_pred = np.dot(qq_backend[:lim_qq,:].T,Wout_q)
    err_backend = mean_squared_error(y_pred,Y_tv_lim)

    # y_pred_backend_dn[i] = y_pred

    LHS = np.dot(qq_open[:lim_qq,:],qq_open[:lim_qq].T)
    RHS = np.dot(qq_open[:lim_qq,:],Y_tv_lim)
    #solve linear system for each tikh_qonov parameter
    Wout_q_dn = np.zeros((tikh_q.size, lim_qq,dim))

    for j in np.arange(tikh_q.size):
        Wout_q_dn[j] = np.linalg.solve(LHS + tikh_q[j]*np.eye(lim_qq), RHS)
        
    Wout_q_dn = Wout_q_dn[0]

    y_pred = np.dot(qq_open[:lim_qq,:].T,Wout_q_dn)
    err_open = mean_squared_error(y_pred,Y_tv_lim)

    LHS = np.dot(qq_backend_dn[:lim_qq,:],qq_backend_dn[:lim_qq].T)
    RHS = np.dot(qq_backend_dn[:lim_qq,:],Y_tv_lim)
    #solve linear system for each tikh_qonov parameter
    Wout_q = np.zeros((tikh_q.size, lim_qq,dim))

    for j in np.arange(tikh_q.size):
        Wout_q[j] = np.linalg.solve(LHS + tikh_q[j]*np.eye(lim_qq), RHS)
        
    Wout_q = Wout_q[0]

    y_pred = np.dot(qq_backend_dn[:lim_qq,:].T,Wout_q)
    err_backend_dn = mean_squared_error(y_pred,Y_tv_lim)

    # y_pred_backend_dn[i] = y_pred

    LHS = np.dot(qq_open_dn[:lim_qq,:],qq_open_dn[:lim_qq].T)
    RHS = np.dot(qq_open_dn[:lim_qq,:],Y_tv_lim)
    #solve linear system for each tikh_qonov parameter
    Wout_q_dn = np.zeros((tikh_q.size, lim_qq,dim))

    for j in np.arange(tikh_q.size):
        Wout_q_dn[j] = np.linalg.solve(LHS + tikh_q[j]*np.eye(lim_qq), RHS)
        
    Wout_q_dn = Wout_q_dn[0]

    y_pred = np.dot(qq_open_dn[:lim_qq,:].T,Wout_q_dn)
    err_open_dn = mean_squared_error(y_pred,Y_tv_lim)


    mse_backend_dn[i] = err_backend_dn
    mse_open_dn [i] = err_open_dn
    

    # y_pred_open_dn[i] = y_pred
    
    
    mse_backend[i] = err_backend
    mse_open[i] = err_open
    
    # y_pred_open_dn[i] = y_pred
    


# print(mse_backend_dn,mse_open_dn)

# %%
# print((mse_backend-mse_backend_dn)*100/mse_backend)

# %%
# print((mse_open-mse_open_dn)*100/mse_open)

# %%
plt.rcParams['text.usetex'] = True
plt.rcParams["figure.figsize"] = (12,4)
plt.rcParams["font.size"] = 12

plt.subplot(1,2,1)
plt.plot(lim_qq_list,mse_backend,label='Backend',marker='x')
plt.plot(lim_qq_list,mse_open,label='Simulated',marker='*')
plt.title("Training Error for various Reservoir States")
plt.ylabel("Mean Squared Error (mse)")
plt.xlabel("Included Reservoir States")
plt.grid()
plt.legend()
# plt.yscale("log")


plt.subplot(1,2,2)
plt.plot(lim_qq_list,mse_backend_dn,label='Backend-Denoised',marker='x')
plt.plot(lim_qq_list,mse_open_dn,label='Simulated-Denoised',marker='*')
plt.title("Training Error for various Reservoir States")
plt.ylabel("Mean Squared Error (mse)")
plt.xlabel("Included Reservoir States")
plt.grid()
plt.legend()
# plt.yscale("log")
plt.show()

# %%
plt.rcParams['text.usetex'] = True
plt.rcParams["figure.figsize"] = (12,4)
plt.rcParams["font.size"] = 12

plt.subplot(1,2,1)
plt.plot(lim_qq_list,mse_backend,label='Backend',marker='x')
plt.plot(lim_qq_list,mse_backend_dn,label='Backend-Denoised',marker='x')

plt.title("Training Error for various Reservoir States")
plt.ylabel("Mean Squared Error (mse)")
plt.xlabel("Included Reservoir States")
plt.grid()
plt.legend()
plt.yscale("log")


plt.subplot(1,2,2)
plt.plot(lim_qq_list,mse_open,label='Simulated',marker='*')
plt.plot(lim_qq_list,mse_open_dn,label='Simulated-Denoised',marker='*')
plt.title("Training Error for various Reservoir States")
plt.ylabel("Mean Squared Error (mse)")
plt.xlabel("Included Reservoir States")
plt.grid()
plt.legend()
plt.yscale("log")
plt.show()

# %%
stop
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 stop
#
# NameError: name 'stop' is not defined

# %%
# plt.plot(lim_qq_list,mse_sv,label='True',marker='x')
plt.rcParams['text.usetex'] = True
plt.rcParams["figure.figsize"] = (6,4)
plt.rcParams["font.size"] = 12


lim_list = 5

plt.plot(y_pred_backend_dn[lim_list],label='Backend-Denoised')
# plt.plot(y_pred_open_dn[lim_list],label='Simulated-Denoised',linestyle='--')
plt.plot(y_pred,label='Simulated-Denoised',linestyle='--')
plt.title("Training Error for various Reservoir States")
plt.ylabel("Kinetic Energy")
plt.xlabel("Included Reservoir States")
plt.grid()
# plt.legend()
# plt.yscale("log")
plt.show()

# %%
# plt.plot(lim_qq_list,mse_sv,label='True',marker='x')
plt.rcParams['text.usetex'] = True
plt.rcParams["figure.figsize"] = (6,4)
plt.rcParams["font.size"] = 12

for i in range(lim_qq_list.shape[0]):
        
    lim_list = int(lim_qq_list[i])
    print(lim_list)
    plt.plot(y_pred_backend_dn[i],label='Backend-Denoised')
    plt.plot(y_pred_open_dn[i],label='Simulated-Denoised',linestyle='--')
    plt.title("Training Error for various Reservoir States {}".format(lim_list))
    plt.ylabel("Mean Squared Error (mse)")
    plt.xlabel("Included Reservoir States")
    plt.grid()

    # plt.yscale("log")
    plt.show()

plt.legend()

# %%
stop

# %% [markdown]
# # Circuit check

# %%
import pickle

with open("./data/MFE/qc_transpiled_decoupled_assigned_meas_{}_MFE".format('ibm_kyoto'), "rb") as fp:
   circuit_list_meas = pickle.load(fp)

# %%
circuit_list_meas[0].depth()

# %%
# circuit_list_meas[0].draw(output='mpl',scale=0.8,idle_wires=False, style="iqp")

# %%
stop

# %% [markdown]
# # Running on backend

# %%
service = QiskitRuntimeService(
    channel='ibm_quantum',
    instance='ibm-q/open/main',
    token='2d5ad9bb4bd1de4e7308dd217cdc49baa416c4b86410bad5d9baa9320dbe037030d115a27e990124e22ecffd0d5e129f571f5690794babdb1d065a4d5734c8c3',
)

# Or save your credentials on disk.
# QiskitRuntimeService.save_account(channel='ibm_quantum', instance='ibm-q/open/main', token='<IBM Quantum API key>')

# %%
service = QiskitRuntimeService(channel="ibm_quantum")
# backend service.least_busy(operational=True, simulator=False)
QiskitRuntimeService.save_account(channel="ibm_quantum", token="2d5ad9bb4bd1de4e7308dd217cdc49baa416c4b86410bad5d9baa9320dbe037030d115a27e990124e22ecffd0d5e129f571f5690794babdb1d065a4d5734c8c3",overwrite=True)
# backend = service.backend("ibm_kyoto")
# print(backend)

# %%
qubits = 7
N_units_q = 2**7


Configurations = ['Linear+Full+FullSymmetric','Linear+Linear+Linear','None+Linear+Linear','None+Full+FullSymmetric','None+Products+Linear']
config_list    = ['config1','config2','config3','config4','config5']
qc_type        = config_list[3]
config         = 4 # for initializing class its +1 of the list above

emulator_list  = ['sv_sim','qasm_sim','fake_brisbane','fake_kyoto','ibm_kyoto']
emulator       = emulator_list[3]

method_list    = ['sv','shots1k','shots5k','shots10k','shots20k','shots30k','shots40k','shots50k','shots75k','shots100k','shots200k','shots1']
shot_list      = [None,1000,5000,10000,20000,30000,40000,50000,75000,100000,200000,400000,1]

## SHOT INPUT
shot_index     = 1

method = method_list[shot_index]
total_shots  = shot_list[shot_index]


shots = total_shots

snapshots = 1
print('Configuration:',qc_type,'Emulator:',emulator,'Total shots:',total_shots,'Individual Shots:',shots)

# Initialize Class
QESN   = QuantumReservoirNetwork(rho_q,epsilon_q,sigma_in_q,tikh_q,bias_in,bias_out,qubits,N_units_q,dim,config,emulator,shots,snapshots)

# Parameterized or not
QESN.method_qc(parameterized=True)


# Transpile for a given backend
trys = 100
# backend =  FakeKyoto()
# backend = FakeBrisbane()
QESN.transpile_param_quantumcircuit(trys,backend,save=True)

# %%
### Move this inside class along with parameterized another function

pt_circuit = QESN.transpiled_qc # Parameterized and transpiled circuit
alpha_q    = QESN.gen_random_unitary(0,4*np.pi)


u_in = np.zeros([U_tv.shape[1],U_tv.shape[2]])
total_runs = U_tv.shape[1]

for kk in range(total_runs):
    u_in[kk] = U_tv[0][kk]
    
#Dynamic Decoupling   
# Get gate durations so the transpiler knows how long each operation takes
durations = backend.target.durations()

# This is the sequence we'll apply to idling qubits
dd_sequence = [XGate(), XGate()]

# Run scheduling and dynamic decoupling passes on circuit
pm = PassManager([ASAPScheduleAnalysis(durations), PadDynamicalDecoupling(durations, dd_sequence)])
ptd_circuit = pm.run(pt_circuit)

print('ptd circuit is Parameterized , Transpiled and Dynamic Decoupled')

# %%
circuit_list = []

for ii in range(total_runs):
    if ii % 100 ==0:
        print(ii)
    comb_val =  np.concatenate((u_in[ii],alpha_q))
    # print(comb_val)
    
    qc_l = ptd_circuit
    for i , j in enumerate(comb_val):
        # print(i,j)
        bound_qc = qc_l.assign_parameters({ptd_circuit.parameters[i]: j})
        qc_l  = bound_qc
        
    circuit_list.append(qc_l)

# %%
circuit_list_meas = []

for mm in range(total_runs):
    if mm % 500 ==0:
        print(mm)
    circ = circuit_list[mm]
    circ.measure_active()
    
    circuit_list_meas.append(circ)

# %%
circuit_list_meas[0:3]

# %%
with Batch(service=service, backend=backend):
    sampler = Sampler()
    job = sampler.run(
        circuits=circuit_list_meas[0:3],  # sample all three circuits
        skip_transpilation=True,
        shots=20000,
    )
    result = job.result()

# %%
# import pickle

# with open("qc_transpiled_decoupled_assigned_meas_{}_MFE".format('ibm_kyoto'), "wb") as fp:   #Pickling
#     pickle.dump(circuit_list_meas, fp)




# >>> with open("test", "rb") as fp:   # Unpickling
# ...   b = pickle.load(fp)

# %%
from qiskit_ibm_runtime import QiskitRuntimeService

# Save an IBM Cloud account.
# QiskitRuntimeService.save_account(channel="ibm_cloud", token="MY_IBM_CLOUD_API_KEY", instance="MY_IBM_CLOUD_CRN")

# Save an IBM Quantum account. # oa1422
# QiskitRuntimeService.save_account(channel="ibm_quantum", token="865e3788ecaf1c7567a6b259263080bf7d445c79d3574a114e85567d9b2f85f9dc9a35c0171ea07e22f50a56f8e7953d5713950ea77242d06ca0eab8d13e1674")

# Save an IBM Quantum account. # oa1248
# QiskitRuntimeService.save_account(channel="ibm_quantum", token="47a8ce3901d959a3a80a5ec03c3c6a5316d3828ca03371095c75d459d7a5aeb3ce0193f549d2ee672ec5f64f8858529487f30380ab58536c16827eaf5f6bf899")

# Save an IBM Quantum account. # ftimp
# QiskitRuntimeService.save_account(channel="ibm_quantum", token="2b186cae522cfafdeadf4fb8d65aa8d4ff5bedec5e34056d1d4b114a309934c108dba865674359e0f054d525d9bc9582e549b669b5a600bef33b6708441cc7d4",overwrite=True)

# Save an IBM Quantum account. # ftoxf
# QiskitRuntimeService.save_account(channel="ibm_quantum", token="ffeb13c7942f9cdeb65b46c60bf54331ac30f5cd8dd395ca3e5b9609f70f6c24008a203584c082e90de61b6c5115cdf23088420b6683e3a00d7678de3d5ad351",overwrite=True)

# Save an IBM Quantum account. # d_ozan
# QiskitRuntimeService.save_account(channel="ibm_quantum", token="9c3aa0414a2c56ca3952d7b35ba95cd39169f531944fd11a7adeb1b7bae7868bf1bb64d3c768e1bcf695c3b679187063072305b3d12fa8434d4dd897aa33368b",overwrite=True)

# %%
from qiskit_ibm_runtime.fake_provider import FakeBrisbane

# from qiskit.visualization.timeline import draw as timeline_draw

from qiskit_ibm_runtime import QiskitRuntimeService

service = QiskitRuntimeService()
#backend = service.backend("ibmq_guadalupe") # Retired

# %% [markdown]
# # Training

# %%
Configurations = ['Linear+Full+FullSymmetric','Linear+Linear+Linear','None+Linear+Linear','None+Full+FullSymmetric','None+Products+Linear']
config_list    = ['config1','config2','config3','config4','config5']
qc_type        = config_list[3]
config         = 4 # for initializing class its +1 of the list above

emulator_list  = ['sv_sim','qasm_sim','fake_brisbane']
emulator       = emulator_list[2]

method_list    = ['sv','shots1k','shots5k','shots10k','shots20k','shots30k','shots40k','shots50k','shots75k','shots100k','shots200k','shots1']
shot_list      = [None,1000,5000,10000,20000,30000,40000,50000,75000,100000,200000,400000,1]

## SHOT INPUT
shot_index     = 1

method = method_list[shot_index]
total_shots  = shot_list[shot_index]


shots = total_shots

snapshots = 1
print('Configuration:',qc_type,'Emulator:',emulator,'Total shots:',total_shots,'Individual Shots:',shots)

# Initialize Class
QESN   = QuantumReservoirNetwork(rho_q,epsilon_q,sigma_in_q,tikh_q,bias_in,bias_out,qubits,N_units_q,dim,config,emulator,shots,snapshots)

# Parameterized or not
QESN.method_qc(parameterized=True)


# Transpile for a given backend
trys = 10 
backend = FakeBrisbane()
QESN.transpile_param_quantumcircuit(trys,backend,save=False)

# If transpiled file already exists
# with open("qc_transpiled_fakebrisbane.qpy", "rb") as qpy_file_read:
#     t_qc = qpy.load(qpy_file_read)[0]

# QESN.transpiled_qc = t_qc




# Generate parameterized quantum circuit for a given configuration
# QESN.gen_param_quantumcircuit()

quantum_training = True
run_training     = True
save_training    = False
load_training    = False

Xa_qq    = []
Woutt_qq    = np.zeros(((qu_ensemble, QESN.N_units+1,dim)))
LHS_qq   = []
RHS_qq   = []
alpha_qc = []

eps_fix  = 0.05
tikh_q   = np.array([1e-12])
eps_q_list = np.linspace(0.05,0.3,qu_ensemble)
eps_q_list = np.ones(len(eps_q_list))*eps_fix
alpha_range    = 4*np.pi

start = timer()

if quantum_training:
    for i in range(qu_ensemble):
        
        print('Network',i+1,' out of ',qu_ensemble)
        seed           = i
        
        # Quantum Variational Part
        QESN.epsilon_q = eps_q_list[i]

        alpha_q          = QESN.gen_random_unitary(i,alpha_range)
        alpha_qc        += [alpha_q]


        if load_training:
            print('Loading existing Wout matrix')
            #hf       = h5py.File('./data/MFE/Woutt_qq='+str(dt)+'-Nres'+str(N_units_q)+'-Ensemble'+str(ensemble)+'-dim'+str(dim)+'-epsilon_q'+str(eps_fix)+'-tikh'+str(tikh_q)+'script')#+'-noise')
            #hf        = h5py.File('./data/MFE/Woutt_qq='+str(dt)+'-Nres'+str(N_units)+'-Ensemble'+str(qu_ensemble)+'-dim'+str(dim)+'-epsilon_q'+str(eps_fix)+'-tikh'+str(tikh_q)+'-scaling'+str(scaling)+'-noise'+str(noise)+'-'+str(method)+str(qc_type))
            hf       = h5py.File('./data/VPT_L63/Woutt_qq='+str(dt)+'-Nres'+str(N_units)+'-Ensemble'+str(ensemble)+'-dim'+str(dim)+'-epsilon_q'+str(eps_fix)+'-tikh'+str(tikh_q)+'-scaling'+str(scaling)+'-noise'+str(noise)+'-'+str(method)+str(qc_type))
            #hf      = h5py.File('./data/{}_New/Woutt_qq='.format(save_fold)+str(dt)+'-Nres'+str(N_units)+'-Ensemble'+str(qu_ensemble)+'-dim'+str(dim)+'-epsilon_q'+str(eps_fix)+'-tikh'+str(tikh_q)+'-scaling'+str(scaling)+'-noise'+str(noise)+'-'+str(method)+str(qc_type))
            #hf      = h5py.File('./data/{}/Woutt_qq='.format(save_fold)+str(dt)+'-Nres'+str(N_units)+'-Ensemble'+str(qu_ensemble)+'-dim'+str(dim)+'-epsilon_q'+str(eps_fix)+'-tikh'+str(tikh_q)+'-scaling'+str(scaling)+'-noise'+str(noise)+'-'+str(method)+str(qc_type))
            
            Woutt_qq       = np.array(hf.get('Woutt_qq'))
            hf.close()
        

        if run_training:
            print('Training...')
            Xa_qc, Woutt_qc, LHS_qc, RHS_qc = QESN.quantum_training(U_washout, U_tv, Y_tv, alpha_qc[i])
                    
            Xa_qq       += [Xa_qc]
            Woutt_qq[i]  = Woutt_qc # saving Output matrix as array 
            LHS_qq      += [LHS_qc]
            RHS_qq      += [RHS_qc]
                
alpha_qq = alpha_qc
# Woutt_qq = Woutt_qq

if load_training:
    Woutt_qq = np.reshape(Woutt_qq,[qu_ensemble, QESN.N_units+1,dim]) # If loading previously saved Woutt , need to reshape 4D to 2D

end = timer()

training_time = (end-start)
print(training_time)


if save_training:
    fln      = ('./data/{}/Woutt_qq='.format(save_fold)+str(dt)+'-Nres'+str(N_units)+'-Ensemble'+str(qu_ensemble)+'-dim'+str(dim)+'-epsilon_q'+str(eps_fix)+'-tikh'+str(tikh_q)+'-scaling'+str(scaling)+'-noise'+str(noise)+'-'+str(method)+str(qc_type))
    hf       = h5py.File(fln,'w')
    hf.create_dataset('Woutt_qq',data=Woutt_qq)
    hf.close()

# %% [markdown]
# # Predictions

# %%
## MODIFY Post processing functionss
quantum_plots = True
N_test   = dim   #number of intervals in the test set
N_tstart = N_washout          # where the first test interval starts
N_intt   = 15*N_lyap          # length of each test set interval
N_fwd    = 1*N_lyap

len_open = N_washout          # Should be < N_washout because of implementation
len_closed = 10*N_lyap

factor = 100*N_lyap           # statistical predictions

Y_tp      =  []
Yh_tp     =  []
Yh_t_qp   =  []
PH_plot_p  =  []
PH_plot_pq =  []
PH_series  = []
PH_series_q  = []

time_series = np.array([0]) # relevant for MFE

for j in range(len(time_series)):
    num_series = time_series[j]
    print('For time series',num_series)

    for i in range(qu_ensemble):
        seed  = i+1
        Win   =  esn.gen_input_matrix(seed)
        W     =  esn.gen_reservoir_matrix(seed)

        if quantum_plots:
            U_wash, Uh_wash , Y_t , Yh_t , PH_plot , Uh_wash_q, Yh_t_q , PH_plot_q = lorenz63_timeseries_plot(N_test,N_tstart,N_intt,N_fwd,j,UU,U,U_test,N_washout,N_lyap,ensemble,N_t,minimum,esn,Win,W,QESN,Woutt,Woutt_qq,alpha_qq,plot=True,quantum=True)
            
            Y_tp       +=  [Y_t]
            Yh_tp      +=  [Yh_t]
            Yh_t_qp    +=  [Yh_t_q]
            PH_plot_p  += [PH_plot[i]]
            PH_plot_pq += [PH_plot_q[i]]
            
        else:
            U_wash, Uh_wash , Y_t , Yh_t , PH_plot , Uh_wash_q, Yh_t_q , PH_plot_q = lorenz63_timeseries_plot(N_test,N_tstart,N_intt,N_fwd,j,UU,U,U_test,N_washout,N_lyap,ensemble,N_t,minimum,esn,Win,W,QESN,Woutt,Woutt_qq,alpha_qq,plot=True,quantum=False)
            Y_tp      +=  [Y_t]
            Yh_tp     +=  [Yh_t]
            PH_plot_p += [PH_plot[i]]
            
    PH_series   += [PH_plot_p]
    PH_series_q += [PH_plot_pq]
